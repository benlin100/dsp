# %%
import pandas as pd 
import numpy as np
import os.path

pd.set_option("display.max_rows",30)
pd.set_option("display.max_columns", None)
pd.set_option('precision', 5)

# %%
np.__version__
# !ls
# Out:
# 1_pandas_jeopardy_example.ipynb jeopardy.csv
# 2_pandas_olive_questions.ipynb  olive.csv
# PythonPandasAnswers.ipynb

# %%
DATA_DIR = os.path.join("olive.csv")
df = pd.read_csv(os.path.join(DATA_DIR))
df.head()
# Out:
#        Unnamed: 0  region  area  palmitic  palmitoleic  stearic  oleic  \
# 0  1.North-Apulia       1     1      1075           75      226   7823
# 1  2.North-Apulia       1     1      1088           73      224   7709
# 2  3.North-Apulia       1     1       911           54      246   8113
# 3  4.North-Apulia       1     1       966           57      240   7952
# 4  5.North-Apulia       1     1      1051           67      259   7771
#
#    linoleic  linolenic  arachidic  eicosenoic
# 0       672         36         60          29
# 1       781         31         61          29
# 2       549         31         63          29
# 3       619         50         78          35
# 4       672         50         80          46

# %%
df_shape = df.shape

# %%
df_shape
# Out:
# (572, 11)

# %%
df_first_2 = df[0:2]
df_first_2
# Out:
#        Unnamed: 0  region  area  palmitic  palmitoleic  stearic  oleic  \
# 0  1.North-Apulia       1     1      1075           75      226   7823
# 1  2.North-Apulia       1     1      1088           73      224   7709
#
#    linoleic  linolenic  arachidic  eicosenoic
# 0       672         36         60          29
# 1       781         31         61          29

# %%
df.dtypes
# Out:
# Unnamed: 0     object
# region          int64
# area            int64
# palmitic        int64
# palmitoleic     int64
# stearic         int64
# oleic           int64
# linoleic        int64
# linolenic       int64
# arachidic       int64
# eicosenoic      int64
# dtype: object

# %%
df['sub_region_raw'] = df['Unnamed: 0']
df.head()
# Out:
#        Unnamed: 0  region  area  palmitic  palmitoleic  stearic  oleic  \
# 0  1.North-Apulia       1     1      1075           75      226   7823
# 1  2.North-Apulia       1     1      1088           73      224   7709
# 2  3.North-Apulia       1     1       911           54      246   8113
# 3  4.North-Apulia       1     1       966           57      240   7952
# 4  5.North-Apulia       1     1      1051           67      259   7771
#
#    linoleic  linolenic  arachidic  eicosenoic  sub_region_raw
# 0       672         36         60          29  1.North-Apulia
# 1       781         31         61          29  2.North-Apulia
# 2       549         31         63          29  3.North-Apulia
# 3       619         50         78          35  4.North-Apulia
# 4       672         50         80          46  5.North-Apulia

# %%
df.rename(columns={'Unnamed: 0':'sub_region_desc'}, inplace=True)
df.head()
# Out:
#   sub_region_desc  region  area  palmitic  palmitoleic  stearic  oleic  \
# 0  1.North-Apulia       1     1      1075           75      226   7823
# 1  2.North-Apulia       1     1      1088           73      224   7709
# 2  3.North-Apulia       1     1       911           54      246   8113
# 3  4.North-Apulia       1     1       966           57      240   7952
# 4  5.North-Apulia       1     1      1051           67      259   7771
#
#    linoleic  linolenic  arachidic  eicosenoic  sub_region_raw
# 0       672         36         60          29  1.North-Apulia
# 1       781         31         61          29  2.North-Apulia
# 2       549         31         63          29  3.North-Apulia
# 3       619         50         78          35  4.North-Apulia
# 4       672         50         80          46  5.North-Apulia

# %%
df.rename(columns={'area':'sub_region'}, inplace=True)

# %%
df.head()
# Out:
#   sub_region_desc  region  sub_region  palmitic  palmitoleic  stearic  oleic  \
# 0  1.North-Apulia       1           1      1075           75      226   7823
# 1  2.North-Apulia       1           1      1088           73      224   7709
# 2  3.North-Apulia       1           1       911           54      246   8113
# 3  4.North-Apulia       1           1       966           57      240   7952
# 4  5.North-Apulia       1           1      1051           67      259   7771
#
#    linoleic  linolenic  arachidic  eicosenoic  sub_region_raw
# 0       672         36         60          29  1.North-Apulia
# 1       781         31         61          29  2.North-Apulia
# 2       549         31         63          29  3.North-Apulia
# 3       619         50         78          35  4.North-Apulia
# 4       672         50         80          46  5.North-Apulia

# %%
df.region.unique()
# Out:
# array([1, 2, 3])

# %%
df.sub_region.unique()
# Out:
# array([1, 2, 3, 4, 5, 6, 9, 7, 8])

# %%
df['sub_region_desc_'] = df.sub_region_desc.str[2:]
df.head(100)
# Out:
#      sub_region_desc  region  sub_region  palmitic  palmitoleic  stearic  \
# 0     1.North-Apulia       1           1      1075           75      226
# 1     2.North-Apulia       1           1      1088           73      224
# 2     3.North-Apulia       1           1       911           54      246
# 3     4.North-Apulia       1           1       966           57      240
# 4     5.North-Apulia       1           1      1051           67      259
# 5     6.North-Apulia       1           1       911           49      268
# 6     7.North-Apulia       1           1       922           66      264
# 7     8.North-Apulia       1           1      1100           61      235
# 8     9.North-Apulia       1           1      1082           60      239
# 9    10.North-Apulia       1           1      1037           55      213
# 10   11.North-Apulia       1           1      1051           35      219
# 11   12.North-Apulia       1           1      1036           59      235
# ...

# %%
df['sub_region_desc'] = df['sub_region_desc'].str.replace(r'[0-9]+\.', "")

# %%
df.head(100)
# Out:
#    sub_region_desc  region  sub_region  palmitic  palmitoleic  stearic  oleic  \
# 0     North-Apulia       1           1      1075           75      226   7823
# 1     North-Apulia       1           1      1088           73      224   7709
# 2     North-Apulia       1           1       911           54      246   8113
# 3     North-Apulia       1           1       966           57      240   7952
# 4     North-Apulia       1           1      1051           67      259   7771
# 5     North-Apulia       1           1       911           49      268   7924
# 6     North-Apulia       1           1       922           66      264   7990
# 7     North-Apulia       1           1      1100           61      235   7728
# 8     North-Apulia       1           1      1082           60      239   7745
# 9     North-Apulia       1           1      1037           55      213   7944
# 10    North-Apulia       1           1      1051           35      219   7978
# ...

# %%
srd_unique = set(df.sub_region_desc.unique())

# %%
srd_unique
# Out:
# {'Calabria',
#  'Coast-Sardinia',
#  'East-Liguria',
#  'Inland-Sardinia',
#  'North-Apulia',
#  'Sicily',
#  'South-Apulia',
#  'Umbria',
#  'West-Liguria'}

# %%
srd_unique = df.sub_region_desc.unique()
set(srd_unique)
# Out:
# {'Calabria',
#  'Coast-Sardinia',
#  'East-Liguria',
#  'Inland-Sardinia',
#  'North-Apulia',
#  'Sicily',
#  'South-Apulia',
#  'Umbria',
#  'West-Liguria'}
